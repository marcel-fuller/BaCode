# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

from tigramite import plotting as tp
from tigramite.pcmci import PCMCI

# Import our custom modules
from causal_core import (
    create_causal_model,
    create_stable_model,
    generate_dataset,
    run_causal_discovery,
    estimate_all_effects,
    compare_adjustment_sets,
    get_optimal_adjustment_set
)

from causal_evaluation import (
    run_pipeline,
    load_dataset,
    load_discovery_results,
    load_effect_results,
    load_all_results_to_dataframe,
    calculate_metrics,
    run_full_study,
    run_extended_parameter_study,
    run_full_extended_study
)

from causal_visualization import (
    plot_causal_graph,
    plot_ts_graph,
    plot_graph_comparison,
    plot_effect_histogram,
    plot_effect_density,
    plot_multimodality_test,
    plot_effect_comparison,
    plot_error_comparison,
    plot_metrics_comparison,
    plot_timing_comparison
)

# For pretty plotting
sns.set_theme(style="whitegrid")
# %matplotlib inline

np.random.randint(0,2**31-1)
# Out:
# 2097774265

# %%
### 1 Par ###
"""
# Import parameter study functions
from causal_evaluation import run_parameter_study

# Define parameters
par = 'noise'
param_values = np.linspace(0.1,2.,20).tolist()  # Values to test
output_dir = output_dir="noise_study_results_{:%Y-%m-%d_%H-%M-%S}".format(datetime.datetime.now())

# Set base parameters
base_params = {
    'auto_coeff': 0.5,
    'cross_coeff': 0.5,
    'noise_sigma': 1,
    'n_vars': 4,
    'T': 5000,  # Smaller dataset for faster execution
    'pc_alpha': 0.05,
    'tau_max': 4,
    'n_boot': 200,  # Fewer bootstrap samples for faster execution
    'effect_pairs': [((0, -2), (3, 0))]  # Focus on one effect pair
}

# Run study (this might take a while)
study_results = run_parameter_study(
    param_name=par, 
    param_values=param_values,
    base_params=base_params,
    output_dir=output_dir,
    seed=None
)

print(f"Parameter study completed. Results saved in {output_dir}")
"""
# Out:
# '\n# Import parameter study functions\nfrom causal_evaluation import run_parameter_study\n\n# Define parameters\npar = \'noise\'\nparam_values = np.linspace(0.1,2.,20).tolist()  # Values to test\noutput_dir = output_dir="noise_study_results_{:%Y-%m-%d_%H-%M-%S}".format(datetime.datetime.now())\n\n# Set base parameters\nbase_params = {\n    \'auto_coeff\': 0.5,\n    \'cross_coeff\': 0.5,\n    \'noise_sigma\': 1,\n    \'n_vars\': 4,\n    \'T\': 5000,  # Smaller dataset for faster execution\n    \'pc_alpha\': 0.05,\n    \'tau_max\': 4,\n    \'n_boot\': 200,  # Fewer bootstrap samples for faster execution\n    \'effect_pairs\': [((0, -2), (3, 0))]  # Focus on one effect pair\n}\n\n# Run study (this might take a while)\nstudy_results = run_parameter_study(\n    param_name=par, \n    param_values=param_values,\n    base_params=base_params,\n    output_dir=output_dir,\n    seed=None\n)\n\nprint(f"Parameter study completed. Results saved in {output_dir}")\n'

# %%
### Full Study ###

## from causal_evaluation import run_full_study
# Define parameter values to test
auto_values = np.repeat(np.linspace(0.01,.99,10),5).tolist()
cross_values = np.repeat(np.linspace(0.01,.99,10),5).tolist()
noise_values = np.repeat(np.linspace(0.1,3.,10),5).tolist()
T_values = np.repeat([200,300,400,500,600,700,800,900,1000,1500,2000,3000,5000],5).tolist()
n_boot_values = np.repeat([10,50,100,200,300],5).tolist()
# Set base parameters
base_params = {
    'auto_coeff': 0.5,
    'cross_coeff': 0.5,
    'noise_sigma': 1,
    'n_vars': 4,
    'T': 500,  # Smaller dataset for faster execution
    'pc_alpha': 0.05,
    'tau_max': 4,
    'n_boot': 100,  # Fewer bootstrap samples for faster execution
    'effect_pairs': [((0, -2), (3, 0))]  # Focus on one effect pair
}

full_results = run_full_extended_study(    
    auto_values=auto_values,
    cross_values=cross_values,
    noise_values=noise_values,
    T_values=T_values, 
    n_boot_values=n_boot_values,
    base_params=base_params,
    output_dir="full_study_results_{:%Y-%m-%d_%H-%M-%S}".format(datetime.datetime.now()),
    seed=None)
# Out:
# == AUTOCORRELATION STUDY ==
#
# Running auto=0.01 (1/50)
# 1676766453
# <class 'list'> [(np.int64(2), np.int64(-3)), (np.int64(2), np.int64(-2)), (np.int64(3), np.int64(-2)), (np.int64(1), np.int64(-2))]
# <class 'list'> [(np.int64(2), np.int64(-2)), (np.int64(0), np.int64(-1))]
# <class 'list'> [(np.int64(2), np.int64(-2)), (np.int64(0), np.int64(-1))]
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
#   Completed in 197.44 seconds
#
# Running auto=0.01 (2/50)
# 1923679041
# <class 'list'> [(np.int64(2), np.int64(-3)), (np.int64(2), np.int64(-2)), (np.int64(3), np.int64(-2)), (np.int64(1), np.int64(-2))]
# <class 'list'> [(np.int64(2), np.int64(-2)), (np.int64(0), np.int64(-3)), (np.int64(0), np.int64(-1))]
# <class 'list'> [(np.int64(2), np.int64(-2)), (np.int64(0), np.int64(-3)), (np.int64(0), np.int64(-1)), (np.int64(1), np.int64(-2))]
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
#   Completed in 244.20 seconds
#
# Running auto=0.01 (3/50)
# 837151506
# <class 'list'> [(np.int64(2), np.int64(-3)), (np.int64(2), np.int64(-2)), (np.int64(3), np.int64(-2)), (np.int64(1), np.int64(-2))]
# <class 'list'> [(np.int64(2), np.int64(-1)), (np.int64(0), np.int64(-1)), (np.int64(2), np.int64(-2)), (np.int64(2), np.int64(-4))]
# <class 'list'> [(np.int64(2), np.int64(-1)), (np.int64(2), np.int64(-2)), (np.int64(0), np.int64(-1))]
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# ...
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# Warning: Graph contains invalid graph edge. For graph_type = stationary_admg only ['-->', '<--', '<->', '<-+', '+->', ''] are allowed. Setting effect to NaN.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 45
#      23 full_results = run_full_extended_study(
#      24     auto_values=auto_values,
#      25     cross_values=cross_values,
#    (...)
#      30     output_dir="full_study_results_{:%Y-%m-%d_%H-%M-%S}".format(datetime.datetime.now()),
#      31     seed=None)
#      33 """
#      34 # Run full study
#      35 full_results = run_full_study(
#    (...)
#      42 )
#      43 """
# ---> 45 full_results = run_full_extended_study(
#      46     auto_values=auto_values,
#      47     cross_values=cross_values,
#      48     noise_values=noise_values,
#      49     T_values=T_values,
#      50     n_boot_values=n_boot_values,
#      51     base_params=base_params,
#      52     output_dir="full_study_results_{:%Y-%m-%d_%H-%M-%S}".format(datetime.datetime.now()),
#      53     seed=None)
#
# File H:\thesis\code\causal_evaluation.py:1156, in run_full_extended_study(auto_values, cross_values, noise_values, T_values, n_boot_values, base_params, output_dir, seed)
#    1154 print("\n== AUTOCORRELATION STUDY ==")
#    1155 start_time = time.time()
# -> 1156 results['auto'] = run_extended_parameter_study(
#    1157     'auto', auto_values, base_params,
#    1158     os.path.join(output_dir, 'auto_study'),
#    1159     seed=seed if seed is not None else None
#    1160 )
#    1161 auto_time = time.time() - start_time
#    1162 overall_timing['auto_study'] = auto_time
#
# File H:\thesis\code\causal_evaluation.py:1057, in run_extended_parameter_study(param_name, param_values, base_params, output_dir, seed)
#    1055 # Run pipeline
#    1056 start_time = time.time()
# -> 1057 result = run_pipeline(
#    1058     auto_coeff=params['auto_coeff'],
#    1059     cross_coeff=params['cross_coeff'],
#    1060     noise_sigma=params['noise_sigma'],
#    1061     n_vars=params['n_vars'],
#    1062     T=params['T'],
#    1063     pc_alpha=params['pc_alpha'],
#    1064     tau_max=params['tau_max'],
#    1065     n_boot=params['n_boot'],
#    1066     effect_pairs=params['effect_pairs'],
#    1067     output_dir=param_dir,
#    1068     seed=run_seed
#    1069 )
#    1071 # Record total time
#    1072 total_time = time.time() - start_time
#
# File H:\thesis\code\causal_evaluation.py:685, in run_pipeline(auto_coeff, cross_coeff, noise_sigma, n_vars, T, pc_alpha, tau_max, n_boot, effect_pairs, output_dir, seed)
#     682 effect_key = f"{X[0]}_{X[1]}_to_{Y[0]}_{Y[1]}"
#     684 # Estimate effects with confidence intervals
# --> 685 effects, adj_sets, cis, times = estimate_all_effects_with_confidence(
#     686     discovery_results, dataset, X, Y, links, noises,
#     687     save_path=os.path.join(output_dir, f'effects_{effect_key}') if output_dir else None
#     688 )
#     690 effect_results[effect_key] = effects
#     691 adjustment_sets[effect_key] = adj_sets
#
# File H:\thesis\code\causal_core.py:1306, in estimate_all_effects_with_confidence(discovery_results, dataframe, X, Y, links, noises, save_path)
#    1304 # Estimate with bootstrap graphs
#    1305 bootstrap_graphs = discovery_results['bootstrap']['boot_results']['graph']
# -> 1306 bootstrap_results, bootstrap_time = estimate_bootstrap_effects_with_confidence(
#    1307     bootstrap_graphs, dataframe, X, Y,
#    1308     save_path=f"{save_path}_bootstrap.json" if save_path else None
#    1309 )
#    1310 results['bootstrap_effects'] = bootstrap_results['effects']
#    1311 results['bootstrap_stats'] = bootstrap_results['stats']
#
# File H:\thesis\code\causal_core.py:1099, in estimate_bootstrap_effects_with_confidence(bootstrap_graphs, dataframe, X, Y, save_path)
#    1097 else:
#    1098     try:
# -> 1099         effect, adj_set, ci, _ = estimate_causal_effect_with_confidence(b_graph, dataframe, X, Y)
#    1100         bootstrap_effects.append(effect)
#    1101         adjustment_sets.append(adj_set)
#
# File H:\thesis\code\causal_core.py:925, in estimate_causal_effect_with_confidence(graph, dataframe, X, Y, save_path)
#     922 with Timer("effect_estimation", save_path) as timer:
#     923     try:
#     924         # Initialize CausalEffects object
# --> 925         causal_effects = CausalEffects(
#     926             graph,
#     927             graph_type='stationary_admg',
#     928             X=[X], Y=[Y],
#     929             S=None,
#     930             hidden_variables=None,
#     931             verbosity=0
#     932         )
#     934         # Check if there is a valid causal path
#     935         if not causal_effects.check_XYS_paths()[0]:
#
# File ~\.conda\envs\tigra\Lib\site-packages\tigramite\causal_effects.py:117, in CausalEffects.__init__(self, graph, graph_type, X, Y, S, hidden_variables, check_SM_overlap, verbosity)
#     114     raise ValueError("XYS overlaps with hidden_variables!")
#     116 # self.tau_max is needed in the Graphs class
# --> 117 Graphs.__init__(self,
#     118                 graph=graph,
#     119                 graph_type=graph_type,
#     120                 tau_max=self.tau_max,
#     121                 hidden_variables=self.hidden_variables,
#     122                 verbosity=verbosity)
#     124 self._check_XYS()
#     126 self.ancX = self._get_ancestors(X)
#
# File ~\.conda\envs\tigra\Lib\site-packages\tigramite\graphs.py:83, in Graphs.__init__(self, graph, graph_type, tau_max, hidden_variables, verbosity)
#      76     self.definite_status = False
#      78 # Not needed for now...
#      79 # self.ignore_time_bounds = False
#      80
#      81 # Construct internal graph from input graph depending on graph type
#      82 # and hidden variables
# ---> 83 self._construct_graph(graph=graph, graph_type=graph_type,
#      84                       hidden_variables=hidden_variables)
#      86 self._check_graph(self.graph)
#
# File ~\.conda\envs\tigra\Lib\site-packages\tigramite\graphs.py:171, in Graphs._construct_graph(self, graph, graph_type, hidden_variables)
#     167 #########################################
#     168 # Use this tau_max and construct ADMG by assuming paths of
#     169 # maximal lag 10*tau_max... TO BE REVISED!
#     170 self.graph = graph
# --> 171 self.graph = self._get_latent_projection_graph(stationary=True)
#     172 self.graph_type = "tsg_admg"
#     173 #########################################
#     174
#     175 # Also create stationary graph extended to tau_max
#
# File ~\.conda\envs\tigra\Lib\site-packages\tigramite\graphs.py:929, in Graphs._get_latent_projection_graph(self, stationary)
#     920 else:
#     921     hidden_by_taumax_here = False
#     923 cond_ii = (
#     924     # tau <= graph_taumax
#     925             # and
#     926             (
#     927             #     graph[i, j, tau] == '<->'
#     928             # or graph[i, j, tau] == '+->' or graph[i, j, tau] == '<-+'))
# --> 929                 self._check_path( #graph=graph,
#     930                             start=[(i, -taui)],
#     931                              end=[(j, -tauj)],
#     932                              conditions=None,
#     933                              starts_with=['<**', '+**'],
#     934                              ends_with=['**>', '**+'],
#     935                              path_type='any',
#     936                              hidden_by_taumax=hidden_by_taumax_here,
#     937                              hidden_variables=hidden_variables_here,
#     938                              stationary_graph=stationary,
#     939                              )))
#     941 if cond_i_xy and not cond_i_yx and not cond_ii:
#     942     aux_graph[i, j, taui, tauj] = "-->"  #graph[i, j, tau]
#
# File ~\.conda\envs\tigra\Lib\site-packages\tigramite\graphs.py:1096, in Graphs._check_path(self, start, end, conditions, starts_with, ends_with, path_type, stationary_graph, hidden_by_taumax, hidden_variables)
#    1091 # print("Get k = ", link_ik, varlag_k)
#    1092 # print("start_from ", start_from)
#    1093 # print("visited    ", visited)
#    1095 if stationary_graph:
# -> 1096     link_neighbors = self._get_adjacents_stationary_graph(graph=self.graph, node=varlag_k, patterns='***',
#    1097                             max_lag=max_lag, exclude=list(start))
#    1098 else:
#    1099     link_neighbors = self._find_adj(node=varlag_k, patterns='***', exclude=list(start), return_link=True)
#
# File ~\.conda\envs\tigra\Lib\site-packages\tigramite\graphs.py:713, in Graphs._get_adjacents_stationary_graph(self, graph, node, patterns, max_lag, exclude)
#     711 for k, lag_ik in zip(*np.where(graph[i,:,:])):
#     712     matches = [self._match_link(patt, graph[i, k, lag_ik]) for patt in patterns]
# --> 713     if np.any(matches):
#     714         match = (k, lag_i + lag_ik)
#     715         if (k, lag_i + lag_ik) not in exclude and (-max_lag <= lag_i + lag_ik <= 0): # or self.ignore_time_bounds):
#
# KeyboardInterrupt:
